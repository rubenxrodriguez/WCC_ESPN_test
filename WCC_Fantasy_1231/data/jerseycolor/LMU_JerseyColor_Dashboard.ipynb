# %% [markdown]
# # 🏀 LMU Jersey Color Analysis Dashboard - Jan 5th 2026
#
# This notebook loads your pre-built outputs:
#
# - `team_jersey_report.csv` (game-level rollup by jersey color)
# - `player_jersey_report2.csv` (player totals + per-game averages by jersey color)
#
# It then displays them with **pretty formatting**, **color gradients**, and a **jersey-color filter**.

# %% [markdown]
# # 🏀 LMU Jersey Color Analysis Dashboard
#
# This notebook loads your pre-built outputs:
#
# - `team_jersey_report2.csv` (game-level rollup by jersey color)
# - `player_jersey_report3.csv` (player totals + per-game averages by jersey color)
#
# It then displays them with **pretty formatting**, **color gradients**, and a **jersey-color filter**.

# %%
import pandas as pd
import numpy as np
from IPython.display import display

TEAM_PATH = r"team_jersey_report2.csv"
PLAYER_PATH = r"player_jersey_report3.csv"

team = pd.read_csv(TEAM_PATH)
players = pd.read_csv(PLAYER_PATH)

# Ensure consistent ordering of jersey colors (optional)
jersey_order = ["white","blue","red","black","gray"]
team["jerseycolor"] = pd.Categorical(team["jerseycolor"], categories=jersey_order, ordered=True)
players["jerseycolor"] = pd.Categorical(players["jerseycolor"], categories=jersey_order, ordered=True)

team = team.sort_values(["jerseycolor"]).reset_index(drop=True)
players = players.sort_values(["jerseycolor","eFG%"], ascending=[True, False]).reset_index(drop=True)

team.head(), players.head()
# Out:
# (  jerseycolor  games  wins  pts_for  pts_against  avg_margin  lmu_efg  \
#  0       white      4   3.0    74.75        67.25        3.75    0.467
#  1        blue      2   1.0    73.00        71.00        1.00    0.445
#  2         red      4   1.0    66.25        68.25       -1.00    0.471
#  3       black      3   1.0    60.67        61.33       -0.33    0.399
#  4        gray      1   1.0    63.00        58.00        2.50    0.455
#
#     opp_efg   win%
#  0    0.514  0.750
#  1    0.501  0.500
#  2    0.525  0.250
#  3    0.512  0.333
#  4    0.523  1.000  ,
#    jerseycolor            Name  gp  pts  ast  reb  fgm  fga  tpm  pts_mean  \
#  0       white  Maya Hernandez   4   64    5   23   27   50    0      16.0
#  1       white     Jess Lawson   4   66    8   31   17   45    1      16.5
#  2       white   Andjela Matic   4   38   17   16   11   35    5       9.5
#  3        blue  Maya Hernandez   2   44    4   20   18   35    0      22.0
#  4        blue     Jess Lawson   2   40    4   15   13   32    1      20.0
#
#     ast_mean  reb_mean   eFG%
#  0      1.25      5.75  0.540
#  1      2.00      7.75  0.389
#  2      4.25      4.00  0.386
#  3      2.00     10.00  0.514
#  4      2.00      7.50  0.422  )

# %%
# ✅ Quick checks
print("Team rows:", len(team))
print("Player rows:", len(players))

print("\nJersey colors in team report:", team["jerseycolor"].astype(str).unique())
print("Jersey colors in player report:", players["jerseycolor"].astype(str).unique())

# Show any missing jerseycolor rows
missing_team = team[team["jerseycolor"].isna()]
missing_players = players[players["jerseycolor"].isna()]

if len(missing_team):
    display(missing_team)
if len(missing_players):
    display(missing_players.head(20))
# Out:
# Team rows: 5
# Player rows: 15
#
# Jersey colors in team report: ['white' 'blue' 'red' 'black' 'gray']
# Jersey colors in player report: ['white' 'blue' 'red' 'black' 'gray']

# %% [markdown]
# ## Team summary

# %%
def _fmt_pct(x, decimals=1):
    if pd.isna(x):
        return ""
    return f"{x*100:.{decimals}f}%"

def _fmt_num(x, decimals=1):
    if pd.isna(x):
        return ""
    return f"{x:.{decimals}f}"

def _fmt_int(x):
    if pd.isna(x):
        return ""
    try:
        return f"{int(x)}"
    except Exception:
        return str(x)

def margin_color(val):
    # green for positive, red for negative
    if pd.isna(val):
        return ""
    alpha = min(abs(val) / 15, 1)  # tune denominator for your typical margins
    if val > 0:
        return f"background-color: rgba(0, 200, 0, {alpha:.2f});"
    if val < 0:
        return f"background-color: rgba(255, 0, 0, {alpha:.2f});"
    return ""

def win_color(val):
    if pd.isna(val):
        return ""
    # val is 0..1
    alpha = min(max(val, 0), 1)
    return f"background-color: rgba(0, 140, 255, {alpha:.2f});"

def efg_color(val):
    if pd.isna(val):
        return ""
    # center around 0.50 (50%)
    diff = val - 0.50
    alpha = min(abs(diff) / 0.10, 1)
    if diff > 0:
        return f"background-color: rgba(0, 200, 0, {alpha:.2f});"
    if diff < 0:
        return f"background-color: rgba(255, 0, 0, {alpha:.2f});"
    return ""

def opp_efg_color(val):
    if pd.isna(val):
        return ""
    # lower is better, so flip the color logic
    diff = 0.50 - val
    alpha = min(abs(diff) / 0.10, 1)
    if diff > 0:
        return f"background-color: rgba(0, 200, 0, {alpha:.2f});"
    if diff < 0:
        return f"background-color: rgba(255, 0, 0, {alpha:.2f});"
    return ""

def nice_team_table(df):
    show = df.copy()
    # keep a friendly column order
    cols = ["jerseycolor","games","wins","win%","pts_for","pts_against","avg_margin","lmu_efg","opp_efg"]
    cols = [c for c in cols if c in show.columns]
    show = show[cols]

    sty = (show.style
            .applymap(margin_color, subset=["avg_margin"] if "avg_margin" in show.columns else [])
            .applymap(win_color, subset=["win%" if "win%" in show.columns else []])
            .applymap(efg_color, subset=["lmu_efg"] if "lmu_efg" in show.columns else [])
            .applymap(opp_efg_color, subset=["opp_efg"] if "opp_efg" in show.columns else [])
            .format({
                "games": _fmt_int,
                "wins": _fmt_int,
                "pts_for": _fmt_int,
                "pts_against": _fmt_int,
                "avg_margin": lambda x: _fmt_num(x, 2),
                "lmu_efg": lambda x: _fmt_pct(x, 1),
                "opp_efg": lambda x: _fmt_pct(x, 1),
                "win%": lambda x: _fmt_pct(x, 1),
            }, na_rep="")
            .set_properties(**{"font-size":"14px"})
            .set_table_styles([
                {"selector":"th", "props":[("font-size","14px"),("text-align","left")]},
                {"selector":"td", "props":[("text-align","left")]}
            ])
            )
    return sty

def nice_player_table(df):
    show = df.copy()
    # suggested column order
    cols = ["jerseycolor","Name","gp","pts","ast","reb","pts_mean","ast_mean","reb_mean","eFG%","fgm","fga","tpm"]
    cols = [c for c in cols if c in show.columns]
    show = show[cols]

    # Color: eFG% and scoring
    subset_efg = ["eFG%"] if "eFG%" in show.columns else []
    subset_pts = ["pts_mean"] if "pts_mean" in show.columns else []

    sty = (show.style
            .applymap(efg_color, subset=subset_efg)
            .background_gradient(subset=subset_pts, axis=0)  # attempts a nice gradient automatically
            .format({
                "gp": _fmt_int,
                "pts": _fmt_int,
                "ast": _fmt_int,
                "reb": _fmt_int,
                "fgm": _fmt_int,
                "fga": _fmt_int,
                "tpm": _fmt_int,
                "pts_mean": lambda x: _fmt_num(x, 1),
                "ast_mean": lambda x: _fmt_num(x, 1),
                "reb_mean": lambda x: _fmt_num(x, 1),
                "eFG%": lambda x: _fmt_pct(x, 1),
            }, na_rep="")
            .set_properties(**{"font-size":"13px"})
            .set_table_styles([
                {"selector":"th", "props":[("font-size","13px"),("text-align","left")]},
                {"selector":"td", "props":[("text-align","left")]}
            ])
            )
    return sty
nice_team_table(team)
# Out:
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_19142/2085106526.py:69: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(margin_color, subset=["avg_margin"] if "avg_margin" in show.columns else [])
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_19142/2085106526.py:70: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(win_color, subset=["win%" if "win%" in show.columns else []])
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_19142/2085106526.py:71: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(efg_color, subset=["lmu_efg"] if "lmu_efg" in show.columns else [])
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_19142/2085106526.py:72: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(opp_efg_color, subset=["opp_efg"] if "opp_efg" in show.columns else [])
# <style type="text/css">
# #T_5fbda th {
#   font-size: 14px;
#   text-align: left;
# }
# #T_5fbda td {
#   text-align: left;
# }
# #T_5fbda_row0_col0, #T_5fbda_row0_col1, #T_5fbda_row0_col2, #T_5fbda_row0_col4, #T_5fbda_row0_col5, #T_5fbda_row1_col0, #T_5fbda_row1_col1, #T_5fbda_row1_col2, #T_5fbda_row1_col4, #T_5fbda_row1_col5, #T_5fbda_row2_col0, #T_5fbda_row2_col1, #T_5fbda_row2_col2, #T_5fbda_row2_col4, #T_5fbda_row2_col5, #T_5fbda_row3_col0, #T_5fbda_row3_col1, #T_5fbda_row3_col2, #T_5fbda_row3_col4, #T_5fbda_row3_col5, #T_5fbda_row4_col0, #T_5fbda_row4_col1, #T_5fbda_row4_col2, #T_5fbda_row4_col4, #T_5fbda_row4_col5 {
#   font-size: 14px;
# }
# #T_5fbda_row0_col3 {
#   background-color: rgba(0, 140, 255, 0.75);
#   font-size: 14px;
# }
# #T_5fbda_row0_col6 {
#   background-color: rgba(0, 200, 0, 0.25);
#   font-size: 14px;
# }
# #T_5fbda_row0_col7 {
#   background-color: rgba(255, 0, 0, 0.33);
#   font-size: 14px;
# }
# #T_5fbda_row0_col8 {
#   background-color: rgba(255, 0, 0, 0.14);
#   font-size: 14px;
# }
# #T_5fbda_row1_col3 {
#   background-color: rgba(0, 140, 255, 0.50);
#   font-size: 14px;
# }
# #T_5fbda_row1_col6 {
#   background-color: rgba(0, 200, 0, 0.07);
#   font-size: 14px;
# }
# #T_5fbda_row1_col7 {
#   background-color: rgba(255, 0, 0, 0.55);
#   font-size: 14px;
# }
# #T_5fbda_row1_col8 {
#   background-color: rgba(255, 0, 0, 0.01);
#   font-size: 14px;
# }
# #T_5fbda_row2_col3 {
#   background-color: rgba(0, 140, 255, 0.25);
#   font-size: 14px;
# }
# #T_5fbda_row2_col6 {
#   background-color: rgba(255, 0, 0, 0.07);
#   font-size: 14px;
# }
# #T_5fbda_row2_col7 {
#   background-color: rgba(255, 0, 0, 0.29);
#   font-size: 14px;
# }
# #T_5fbda_row2_col8 {
#   background-color: rgba(255, 0, 0, 0.25);
#   font-size: 14px;
# }
# #T_5fbda_row3_col3 {
#   background-color: rgba(0, 140, 255, 0.33);
#   font-size: 14px;
# }
# #T_5fbda_row3_col6 {
#   background-color: rgba(255, 0, 0, 0.02);
#   font-size: 14px;
# }
# #T_5fbda_row3_col7 {
#   background-color: rgba(255, 0, 0, 1.00);
#   font-size: 14px;
# }
# #T_5fbda_row3_col8 {
#   background-color: rgba(255, 0, 0, 0.12);
#   font-size: 14px;
# }
# #T_5fbda_row4_col3 {
#   background-color: rgba(0, 140, 255, 1.00);
#   font-size: 14px;
# }
# #T_5fbda_row4_col6 {
#   background-color: rgba(0, 200, 0, 0.17);
#   font-size: 14px;
# }
# #T_5fbda_row4_col7 {
#   background-color: rgba(255, 0, 0, 0.45);
#   font-size: 14px;
# }
# #T_5fbda_row4_col8 {
#   background-color: rgba(255, 0, 0, 0.23);
#   font-size: 14px;
# }
# </style>
# <table id="T_5fbda">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fbda_level0_col0" class="col_heading level0 col0" >jerseycolor</th>
#       <th id="T_5fbda_level0_col1" class="col_heading level0 col1" >games</th>
#       <th id="T_5fbda_level0_col2" class="col_heading level0 col2" >wins</th>
#       <th id="T_5fbda_level0_col3" class="col_heading level0 col3" >win%</th>
#       <th id="T_5fbda_level0_col4" class="col_heading level0 col4" >pts_for</th>
#       <th id="T_5fbda_level0_col5" class="col_heading level0 col5" >pts_against</th>
#       <th id="T_5fbda_level0_col6" class="col_heading level0 col6" >avg_margin</th>
#       <th id="T_5fbda_level0_col7" class="col_heading level0 col7" >lmu_efg</th>
#       <th id="T_5fbda_level0_col8" class="col_heading level0 col8" >opp_efg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fbda_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5fbda_row0_col0" class="data row0 col0" >white</td>
#       <td id="T_5fbda_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_5fbda_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_5fbda_row0_col3" class="data row0 col3" >75.0%</td>
#       <td id="T_5fbda_row0_col4" class="data row0 col4" >74</td>
#       <td id="T_5fbda_row0_col5" class="data row0 col5" >67</td>
#       <td id="T_5fbda_row0_col6" class="data row0 col6" >3.75</td>
#       <td id="T_5fbda_row0_col7" class="data row0 col7" >46.7%</td>
#       <td id="T_5fbda_row0_col8" class="data row0 col8" >51.4%</td>
#     </tr>
#     <tr>
#       <th id="T_5fbda_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5fbda_row1_col0" class="data row1 col0" >blue</td>
#       <td id="T_5fbda_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_5fbda_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_5fbda_row1_col3" class="data row1 col3" >50.0%</td>
#       <td id="T_5fbda_row1_col4" class="data row1 col4" >73</td>
#       <td id="T_5fbda_row1_col5" class="data row1 col5" >71</td>
#       <td id="T_5fbda_row1_col6" class="data row1 col6" >1.00</td>
#       <td id="T_5fbda_row1_col7" class="data row1 col7" >44.5%</td>
#       <td id="T_5fbda_row1_col8" class="data row1 col8" >50.1%</td>
#     </tr>
#     <tr>
#       <th id="T_5fbda_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5fbda_row2_col0" class="data row2 col0" >red</td>
#       <td id="T_5fbda_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_5fbda_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_5fbda_row2_col3" class="data row2 col3" >25.0%</td>
#       <td id="T_5fbda_row2_col4" class="data row2 col4" >66</td>
#       <td id="T_5fbda_row2_col5" class="data row2 col5" >68</td>
#       <td id="T_5fbda_row2_col6" class="data row2 col6" >-1.00</td>
#       <td id="T_5fbda_row2_col7" class="data row2 col7" >47.1%</td>
#       <td id="T_5fbda_row2_col8" class="data row2 col8" >52.5%</td>
#     </tr>
#     <tr>
#       <th id="T_5fbda_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5fbda_row3_col0" class="data row3 col0" >black</td>
#       <td id="T_5fbda_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_5fbda_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_5fbda_row3_col3" class="data row3 col3" >33.3%</td>
#       <td id="T_5fbda_row3_col4" class="data row3 col4" >60</td>
#       <td id="T_5fbda_row3_col5" class="data row3 col5" >61</td>
#       <td id="T_5fbda_row3_col6" class="data row3 col6" >-0.33</td>
#       <td id="T_5fbda_row3_col7" class="data row3 col7" >39.9%</td>
#       <td id="T_5fbda_row3_col8" class="data row3 col8" >51.2%</td>
#     </tr>
#     <tr>
#       <th id="T_5fbda_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5fbda_row4_col0" class="data row4 col0" >gray</td>
#       <td id="T_5fbda_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_5fbda_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_5fbda_row4_col3" class="data row4 col3" >100.0%</td>
#       <td id="T_5fbda_row4_col4" class="data row4 col4" >63</td>
#       <td id="T_5fbda_row4_col5" class="data row4 col5" >58</td>
#       <td id="T_5fbda_row4_col6" class="data row4 col6" >2.50</td>
#       <td id="T_5fbda_row4_col7" class="data row4 col7" >45.5%</td>
#       <td id="T_5fbda_row4_col8" class="data row4 col8" >52.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 📊 Team report by jersey color
display(nice_team_table(team))
# Out:
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_19142/2085106526.py:69: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(margin_color, subset=["avg_margin"] if "avg_margin" in show.columns else [])
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_19142/2085106526.py:70: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(win_color, subset=["win%" if "win%" in show.columns else []])
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_19142/2085106526.py:71: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(efg_color, subset=["lmu_efg"] if "lmu_efg" in show.columns else [])
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_19142/2085106526.py:72: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(opp_efg_color, subset=["opp_efg"] if "opp_efg" in show.columns else [])
# <style type="text/css">
# #T_fc9fc th {
#   font-size: 14px;
#   text-align: left;
# }
# #T_fc9fc td {
#   text-align: left;
# }
# #T_fc9fc_row0_col0, #T_fc9fc_row0_col1, #T_fc9fc_row0_col2, #T_fc9fc_row0_col4, #T_fc9fc_row0_col5, #T_fc9fc_row1_col0, #T_fc9fc_row1_col1, #T_fc9fc_row1_col2, #T_fc9fc_row1_col4, #T_fc9fc_row1_col5, #T_fc9fc_row2_col0, #T_fc9fc_row2_col1, #T_fc9fc_row2_col2, #T_fc9fc_row2_col4, #T_fc9fc_row2_col5, #T_fc9fc_row3_col0, #T_fc9fc_row3_col1, #T_fc9fc_row3_col2, #T_fc9fc_row3_col4, #T_fc9fc_row3_col5, #T_fc9fc_row4_col0, #T_fc9fc_row4_col1, #T_fc9fc_row4_col2, #T_fc9fc_row4_col4, #T_fc9fc_row4_col5 {
#   font-size: 14px;
# }
# #T_fc9fc_row0_col3 {
#   background-color: rgba(0, 140, 255, 0.75);
#   font-size: 14px;
# }
# #T_fc9fc_row0_col6 {
#   background-color: rgba(0, 200, 0, 0.25);
#   font-size: 14px;
# }
# #T_fc9fc_row0_col7 {
#   background-color: rgba(255, 0, 0, 0.33);
#   font-size: 14px;
# }
# #T_fc9fc_row0_col8 {
#   background-color: rgba(255, 0, 0, 0.14);
#   font-size: 14px;
# }
# #T_fc9fc_row1_col3 {
#   background-color: rgba(0, 140, 255, 0.50);
#   font-size: 14px;
# }
# #T_fc9fc_row1_col6 {
#   background-color: rgba(0, 200, 0, 0.07);
#   font-size: 14px;
# }
# #T_fc9fc_row1_col7 {
#   background-color: rgba(255, 0, 0, 0.55);
#   font-size: 14px;
# }
# #T_fc9fc_row1_col8 {
#   background-color: rgba(255, 0, 0, 0.01);
#   font-size: 14px;
# }
# #T_fc9fc_row2_col3 {
#   background-color: rgba(0, 140, 255, 0.25);
#   font-size: 14px;
# }
# #T_fc9fc_row2_col6 {
#   background-color: rgba(255, 0, 0, 0.07);
#   font-size: 14px;
# }
# #T_fc9fc_row2_col7 {
#   background-color: rgba(255, 0, 0, 0.29);
#   font-size: 14px;
# }
# #T_fc9fc_row2_col8 {
#   background-color: rgba(255, 0, 0, 0.25);
#   font-size: 14px;
# }
# #T_fc9fc_row3_col3 {
#   background-color: rgba(0, 140, 255, 0.33);
#   font-size: 14px;
# }
# #T_fc9fc_row3_col6 {
#   background-color: rgba(255, 0, 0, 0.02);
#   font-size: 14px;
# }
# #T_fc9fc_row3_col7 {
#   background-color: rgba(255, 0, 0, 1.00);
#   font-size: 14px;
# }
# #T_fc9fc_row3_col8 {
#   background-color: rgba(255, 0, 0, 0.12);
#   font-size: 14px;
# }
# #T_fc9fc_row4_col3 {
#   background-color: rgba(0, 140, 255, 1.00);
#   font-size: 14px;
# }
# #T_fc9fc_row4_col6 {
#   background-color: rgba(0, 200, 0, 0.17);
#   font-size: 14px;
# }
# #T_fc9fc_row4_col7 {
#   background-color: rgba(255, 0, 0, 0.45);
#   font-size: 14px;
# }
# #T_fc9fc_row4_col8 {
#   background-color: rgba(255, 0, 0, 0.23);
#   font-size: 14px;
# }
# </style>
# <table id="T_fc9fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc9fc_level0_col0" class="col_heading level0 col0" >jerseycolor</th>
#       <th id="T_fc9fc_level0_col1" class="col_heading level0 col1" >games</th>
#       <th id="T_fc9fc_level0_col2" class="col_heading level0 col2" >wins</th>
#       <th id="T_fc9fc_level0_col3" class="col_heading level0 col3" >win%</th>
#       <th id="T_fc9fc_level0_col4" class="col_heading level0 col4" >pts_for</th>
#       <th id="T_fc9fc_level0_col5" class="col_heading level0 col5" >pts_against</th>
#       <th id="T_fc9fc_level0_col6" class="col_heading level0 col6" >avg_margin</th>
#       <th id="T_fc9fc_level0_col7" class="col_heading level0 col7" >lmu_efg</th>
#       <th id="T_fc9fc_level0_col8" class="col_heading level0 col8" >opp_efg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc9fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc9fc_row0_col0" class="data row0 col0" >white</td>
#       <td id="T_fc9fc_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_fc9fc_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_fc9fc_row0_col3" class="data row0 col3" >75.0%</td>
#       <td id="T_fc9fc_row0_col4" class="data row0 col4" >74</td>
#       <td id="T_fc9fc_row0_col5" class="data row0 col5" >67</td>
#       <td id="T_fc9fc_row0_col6" class="data row0 col6" >3.75</td>
#       <td id="T_fc9fc_row0_col7" class="data row0 col7" >46.7%</td>
#       <td id="T_fc9fc_row0_col8" class="data row0 col8" >51.4%</td>
#     </tr>
#     <tr>
#       <th id="T_fc9fc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc9fc_row1_col0" class="data row1 col0" >blue</td>
#       <td id="T_fc9fc_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_fc9fc_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_fc9fc_row1_col3" class="data row1 col3" >50.0%</td>
#       <td id="T_fc9fc_row1_col4" class="data row1 col4" >73</td>
#       <td id="T_fc9fc_row1_col5" class="data row1 col5" >71</td>
#       <td id="T_fc9fc_row1_col6" class="data row1 col6" >1.00</td>
#       <td id="T_fc9fc_row1_col7" class="data row1 col7" >44.5%</td>
#       <td id="T_fc9fc_row1_col8" class="data row1 col8" >50.1%</td>
#     </tr>
#     <tr>
#       <th id="T_fc9fc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc9fc_row2_col0" class="data row2 col0" >red</td>
#       <td id="T_fc9fc_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_fc9fc_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_fc9fc_row2_col3" class="data row2 col3" >25.0%</td>
#       <td id="T_fc9fc_row2_col4" class="data row2 col4" >66</td>
#       <td id="T_fc9fc_row2_col5" class="data row2 col5" >68</td>
#       <td id="T_fc9fc_row2_col6" class="data row2 col6" >-1.00</td>
#       <td id="T_fc9fc_row2_col7" class="data row2 col7" >47.1%</td>
#       <td id="T_fc9fc_row2_col8" class="data row2 col8" >52.5%</td>
#     </tr>
#     <tr>
#       <th id="T_fc9fc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc9fc_row3_col0" class="data row3 col0" >black</td>
#       <td id="T_fc9fc_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_fc9fc_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_fc9fc_row3_col3" class="data row3 col3" >33.3%</td>
#       <td id="T_fc9fc_row3_col4" class="data row3 col4" >60</td>
#       <td id="T_fc9fc_row3_col5" class="data row3 col5" >61</td>
#       <td id="T_fc9fc_row3_col6" class="data row3 col6" >-0.33</td>
#       <td id="T_fc9fc_row3_col7" class="data row3 col7" >39.9%</td>
#       <td id="T_fc9fc_row3_col8" class="data row3 col8" >51.2%</td>
#     </tr>
#     <tr>
#       <th id="T_fc9fc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fc9fc_row4_col0" class="data row4 col0" >gray</td>
#       <td id="T_fc9fc_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_fc9fc_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_fc9fc_row4_col3" class="data row4 col3" >100.0%</td>
#       <td id="T_fc9fc_row4_col4" class="data row4 col4" >63</td>
#       <td id="T_fc9fc_row4_col5" class="data row4 col5" >58</td>
#       <td id="T_fc9fc_row4_col6" class="data row4 col6" >2.50</td>
#       <td id="T_fc9fc_row4_col7" class="data row4 col7" >45.5%</td>
#       <td id="T_fc9fc_row4_col8" class="data row4 col8" >52.3%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Player breakdown (filter + sort)

# %%
import ipywidgets as widgets

options = ["(all)"] + [c for c in team["jerseycolor"].dropna().astype(str).unique().tolist()]
dropdown = widgets.Dropdown(options=options, value="(all)", description="Jersey:", layout=widgets.Layout(width="250px"))
sort_dropdown = widgets.Dropdown(
    options=["eFG%","pts_mean","ast_mean","reb_mean","gp"],
    value="eFG%",
    description="Sort:",
    layout=widgets.Layout(width="250px")
)
ascending_toggle = widgets.Checkbox(value=False, description="Ascending", indent=False)

display(widgets.HBox([dropdown, sort_dropdown, ascending_toggle]))

def show_filtered(jersey, sort_by, ascending):
    if jersey == "(all)":
        dfp = players.copy()
    else:
        dfp = players[players["jerseycolor"].astype(str) == jersey].copy()
    if sort_by in dfp.columns:
        dfp = dfp.sort_values(sort_by, ascending=ascending)
    display(nice_player_table(dfp.reset_index(drop=True)))

out = widgets.interactive_output(show_filtered, {
    "jersey": dropdown,
    "sort_by": sort_dropdown,
    "ascending": ascending_toggle
})
display(out)
# Out:
# HBox(children=(Dropdown(description='Jersey:', layout=Layout(width='250px'), options=('(all)', 'white', 'blue'…
# Output()

# %% [markdown]
# # 🏀 LMU Jersey Color Analysis Dashboard
#
# This notebook loads your pre-built outputs:
#
# - `team_jersey_report.csv` (game-level rollup by jersey color)
# - `player_jersey_report2.csv` (player totals + per-game averages by jersey color)
#
# It then displays them with **pretty formatting**, **color gradients**, and a **jersey-color filter**.

# %%
import pandas as pd
import numpy as np
from IPython.display import display

TEAM_PATH = r"team_jersey_report.csv"
PLAYER_PATH = r"player_jersey_report2.csv"

team = pd.read_csv(TEAM_PATH)
players = pd.read_csv(PLAYER_PATH)

# Ensure consistent ordering of jersey colors (optional)
jersey_order = ["white","blue","red","black","gray"]
team["jerseycolor"] = pd.Categorical(team["jerseycolor"], categories=jersey_order, ordered=True)
players["jerseycolor"] = pd.Categorical(players["jerseycolor"], categories=jersey_order, ordered=True)

team = team.sort_values(["jerseycolor"]).reset_index(drop=True)
players = players.sort_values(["jerseycolor","eFG%"], ascending=[True, False]).reset_index(drop=True)

team.head(), players.head()
# Out:
# (  jerseycolor  games  wins  pts_for  pts_against  avg_margin  lmu_efg  \
#  0       white      4   3.0    74.75        67.25        3.75    0.467
#  1        blue      1   1.0    64.00        57.00        3.50    0.466
#  2         red      3   1.0    61.67        62.00       -0.17    0.473
#  3       black      2   0.0    57.50        63.00       -2.75    0.375
#  4        gray      1   1.0    63.00        58.00        2.50    0.455
#
#     opp_efg   win%
#  0    0.514  0.750
#  1    0.435  1.000
#  2    0.529  0.333
#  3    0.530  0.000
#  4    0.523  1.000  ,
#    jerseycolor            Name  gp  pts  ast  reb  fgm  fga  tpm  pts_mean  \
#  0       white  Maya Hernandez   4   64    5   23   27   50    0      16.0
#  1       white     Jess Lawson   4   66    8   31   17   45    1      16.5
#  2       white   Andjela Matic   4   38   17   16   11   35    5       9.5
#  3        blue  Maya Hernandez   1   25    3   10   11   19    0      25.0
#  4        blue     Jess Lawson   1    8    2    6    2    8    1       8.0
#
#     ast_mean  reb_mean   eFG%
#  0      1.25      5.75  0.540
#  1      2.00      7.75  0.389
#  2      4.25      4.00  0.386
#  3      3.00     10.00  0.579
#  4      2.00      6.00  0.312  )

# %%
# ✅ Quick checks
print("Team rows:", len(team))
print("Player rows:", len(players))

print("\nJersey colors in team report:", team["jerseycolor"].astype(str).unique())
print("Jersey colors in player report:", players["jerseycolor"].astype(str).unique())

# Show any missing jerseycolor rows
missing_team = team[team["jerseycolor"].isna()]
missing_players = players[players["jerseycolor"].isna()]

if len(missing_team):
    display(missing_team)
if len(missing_players):
    display(missing_players.head(20))
# Out:
# Team rows: 5
# Player rows: 15
#
# Jersey colors in team report: ['white' 'blue' 'red' 'black' 'gray']
# Jersey colors in player report: ['white' 'blue' 'red' 'black' 'gray']

# %% [markdown]
# ## Team summary

# %%
def _fmt_pct(x, decimals=1):
    if pd.isna(x):
        return ""
    return f"{x*100:.{decimals}f}%"

def _fmt_num(x, decimals=1):
    if pd.isna(x):
        return ""
    return f"{x:.{decimals}f}"

def _fmt_int(x):
    if pd.isna(x):
        return ""
    try:
        return f"{int(x)}"
    except Exception:
        return str(x)

def margin_color(val):
    # green for positive, red for negative
    if pd.isna(val):
        return ""
    alpha = min(abs(val) / 15, 1)  # tune denominator for your typical margins
    if val > 0:
        return f"background-color: rgba(0, 200, 0, {alpha:.2f});"
    if val < 0:
        return f"background-color: rgba(255, 0, 0, {alpha:.2f});"
    return ""

def win_color(val):
    if pd.isna(val):
        return ""
    # val is 0..1
    alpha = min(max(val, 0), 1)
    return f"background-color: rgba(0, 140, 255, {alpha:.2f});"

def efg_color(val):
    if pd.isna(val):
        return ""
    # center around 0.50 (50%)
    diff = val - 0.50
    alpha = min(abs(diff) / 0.10, 1)
    if diff > 0:
        return f"background-color: rgba(0, 200, 0, {alpha:.2f});"
    if diff < 0:
        return f"background-color: rgba(255, 0, 0, {alpha:.2f});"
    return ""

def opp_efg_color(val):
    if pd.isna(val):
        return ""
    # lower is better, so flip the color logic
    diff = 0.50 - val
    alpha = min(abs(diff) / 0.10, 1)
    if diff > 0:
        return f"background-color: rgba(0, 200, 0, {alpha:.2f});"
    if diff < 0:
        return f"background-color: rgba(255, 0, 0, {alpha:.2f});"
    return ""

def nice_team_table(df):
    show = df.copy()
    # keep a friendly column order
    cols = ["jerseycolor","games","wins","win%","pts_for","pts_against","avg_margin","lmu_efg","opp_efg"]
    cols = [c for c in cols if c in show.columns]
    show = show[cols]

    sty = (show.style
            .applymap(margin_color, subset=["avg_margin"] if "avg_margin" in show.columns else [])
            .applymap(win_color, subset=["win%" if "win%" in show.columns else []])
            .applymap(efg_color, subset=["lmu_efg"] if "lmu_efg" in show.columns else [])
            .applymap(opp_efg_color, subset=["opp_efg"] if "opp_efg" in show.columns else [])
            .format({
                "games": _fmt_int,
                "wins": _fmt_int,
                "pts_for": _fmt_int,
                "pts_against": _fmt_int,
                "avg_margin": lambda x: _fmt_num(x, 2),
                "lmu_efg": lambda x: _fmt_pct(x, 1),
                "opp_efg": lambda x: _fmt_pct(x, 1),
                "win%": lambda x: _fmt_pct(x, 1),
            }, na_rep="")
            .set_properties(**{"font-size":"14px"})
            .set_table_styles([
                {"selector":"th", "props":[("font-size","14px"),("text-align","left")]},
                {"selector":"td", "props":[("text-align","left")]}
            ])
            )
    return sty

def nice_player_table(df):
    show = df.copy()
    # suggested column order
    cols = ["jerseycolor","Name","gp","pts","ast","reb","pts_mean","ast_mean","reb_mean","eFG%","fgm","fga","tpm"]
    cols = [c for c in cols if c in show.columns]
    show = show[cols]

    # Color: eFG% and scoring
    subset_efg = ["eFG%"] if "eFG%" in show.columns else []
    subset_pts = ["pts_mean"] if "pts_mean" in show.columns else []

    sty = (show.style
            .applymap(efg_color, subset=subset_efg)
            .background_gradient(subset=subset_pts, axis=0)  # attempts a nice gradient automatically
            .format({
                "gp": _fmt_int,
                "pts": _fmt_int,
                "ast": _fmt_int,
                "reb": _fmt_int,
                "fgm": _fmt_int,
                "fga": _fmt_int,
                "tpm": _fmt_int,
                "pts_mean": lambda x: _fmt_num(x, 1),
                "ast_mean": lambda x: _fmt_num(x, 1),
                "reb_mean": lambda x: _fmt_num(x, 1),
                "eFG%": lambda x: _fmt_pct(x, 1),
            }, na_rep="")
            .set_properties(**{"font-size":"13px"})
            .set_table_styles([
                {"selector":"th", "props":[("font-size","13px"),("text-align","left")]},
                {"selector":"td", "props":[("text-align","left")]}
            ])
            )
    return sty
nice_team_table(team)
# Out:
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_8324/2085106526.py:69: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(margin_color, subset=["avg_margin"] if "avg_margin" in show.columns else [])
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_8324/2085106526.py:70: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(win_color, subset=["win%" if "win%" in show.columns else []])
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_8324/2085106526.py:71: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(efg_color, subset=["lmu_efg"] if "lmu_efg" in show.columns else [])
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_8324/2085106526.py:72: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(opp_efg_color, subset=["opp_efg"] if "opp_efg" in show.columns else [])
# <style type="text/css">
# #T_db0c7 th {
#   font-size: 14px;
#   text-align: left;
# }
# #T_db0c7 td {
#   text-align: left;
# }
# #T_db0c7_row0_col0, #T_db0c7_row0_col1, #T_db0c7_row0_col2, #T_db0c7_row0_col4, #T_db0c7_row0_col5, #T_db0c7_row1_col0, #T_db0c7_row1_col1, #T_db0c7_row1_col2, #T_db0c7_row1_col4, #T_db0c7_row1_col5, #T_db0c7_row2_col0, #T_db0c7_row2_col1, #T_db0c7_row2_col2, #T_db0c7_row2_col4, #T_db0c7_row2_col5, #T_db0c7_row3_col0, #T_db0c7_row3_col1, #T_db0c7_row3_col2, #T_db0c7_row3_col4, #T_db0c7_row3_col5, #T_db0c7_row4_col0, #T_db0c7_row4_col1, #T_db0c7_row4_col2, #T_db0c7_row4_col4, #T_db0c7_row4_col5 {
#   font-size: 14px;
# }
# #T_db0c7_row0_col3 {
#   background-color: rgba(0, 140, 255, 0.75);
#   font-size: 14px;
# }
# #T_db0c7_row0_col6 {
#   background-color: rgba(0, 200, 0, 0.25);
#   font-size: 14px;
# }
# #T_db0c7_row0_col7 {
#   background-color: rgba(255, 0, 0, 0.33);
#   font-size: 14px;
# }
# #T_db0c7_row0_col8 {
#   background-color: rgba(255, 0, 0, 0.14);
#   font-size: 14px;
# }
# #T_db0c7_row1_col3, #T_db0c7_row4_col3 {
#   background-color: rgba(0, 140, 255, 1.00);
#   font-size: 14px;
# }
# #T_db0c7_row1_col6 {
#   background-color: rgba(0, 200, 0, 0.23);
#   font-size: 14px;
# }
# #T_db0c7_row1_col7 {
#   background-color: rgba(255, 0, 0, 0.34);
#   font-size: 14px;
# }
# #T_db0c7_row1_col8 {
#   background-color: rgba(0, 200, 0, 0.65);
#   font-size: 14px;
# }
# #T_db0c7_row2_col3 {
#   background-color: rgba(0, 140, 255, 0.33);
#   font-size: 14px;
# }
# #T_db0c7_row2_col6 {
#   background-color: rgba(255, 0, 0, 0.01);
#   font-size: 14px;
# }
# #T_db0c7_row2_col7 {
#   background-color: rgba(255, 0, 0, 0.27);
#   font-size: 14px;
# }
# #T_db0c7_row2_col8 {
#   background-color: rgba(255, 0, 0, 0.29);
#   font-size: 14px;
# }
# #T_db0c7_row3_col3 {
#   background-color: rgba(0, 140, 255, 0.00);
#   font-size: 14px;
# }
# #T_db0c7_row3_col6 {
#   background-color: rgba(255, 0, 0, 0.18);
#   font-size: 14px;
# }
# #T_db0c7_row3_col7 {
#   background-color: rgba(255, 0, 0, 1.00);
#   font-size: 14px;
# }
# #T_db0c7_row3_col8 {
#   background-color: rgba(255, 0, 0, 0.30);
#   font-size: 14px;
# }
# #T_db0c7_row4_col6 {
#   background-color: rgba(0, 200, 0, 0.17);
#   font-size: 14px;
# }
# #T_db0c7_row4_col7 {
#   background-color: rgba(255, 0, 0, 0.45);
#   font-size: 14px;
# }
# #T_db0c7_row4_col8 {
#   background-color: rgba(255, 0, 0, 0.23);
#   font-size: 14px;
# }
# </style>
# <table id="T_db0c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db0c7_level0_col0" class="col_heading level0 col0" >jerseycolor</th>
#       <th id="T_db0c7_level0_col1" class="col_heading level0 col1" >games</th>
#       <th id="T_db0c7_level0_col2" class="col_heading level0 col2" >wins</th>
#       <th id="T_db0c7_level0_col3" class="col_heading level0 col3" >win%</th>
#       <th id="T_db0c7_level0_col4" class="col_heading level0 col4" >pts_for</th>
#       <th id="T_db0c7_level0_col5" class="col_heading level0 col5" >pts_against</th>
#       <th id="T_db0c7_level0_col6" class="col_heading level0 col6" >avg_margin</th>
#       <th id="T_db0c7_level0_col7" class="col_heading level0 col7" >lmu_efg</th>
#       <th id="T_db0c7_level0_col8" class="col_heading level0 col8" >opp_efg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db0c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db0c7_row0_col0" class="data row0 col0" >white</td>
#       <td id="T_db0c7_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_db0c7_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_db0c7_row0_col3" class="data row0 col3" >75.0%</td>
#       <td id="T_db0c7_row0_col4" class="data row0 col4" >74</td>
#       <td id="T_db0c7_row0_col5" class="data row0 col5" >67</td>
#       <td id="T_db0c7_row0_col6" class="data row0 col6" >3.75</td>
#       <td id="T_db0c7_row0_col7" class="data row0 col7" >46.7%</td>
#       <td id="T_db0c7_row0_col8" class="data row0 col8" >51.4%</td>
#     </tr>
#     <tr>
#       <th id="T_db0c7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_db0c7_row1_col0" class="data row1 col0" >blue</td>
#       <td id="T_db0c7_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_db0c7_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_db0c7_row1_col3" class="data row1 col3" >100.0%</td>
#       <td id="T_db0c7_row1_col4" class="data row1 col4" >64</td>
#       <td id="T_db0c7_row1_col5" class="data row1 col5" >57</td>
#       <td id="T_db0c7_row1_col6" class="data row1 col6" >3.50</td>
#       <td id="T_db0c7_row1_col7" class="data row1 col7" >46.6%</td>
#       <td id="T_db0c7_row1_col8" class="data row1 col8" >43.5%</td>
#     </tr>
#     <tr>
#       <th id="T_db0c7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_db0c7_row2_col0" class="data row2 col0" >red</td>
#       <td id="T_db0c7_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_db0c7_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_db0c7_row2_col3" class="data row2 col3" >33.3%</td>
#       <td id="T_db0c7_row2_col4" class="data row2 col4" >61</td>
#       <td id="T_db0c7_row2_col5" class="data row2 col5" >62</td>
#       <td id="T_db0c7_row2_col6" class="data row2 col6" >-0.17</td>
#       <td id="T_db0c7_row2_col7" class="data row2 col7" >47.3%</td>
#       <td id="T_db0c7_row2_col8" class="data row2 col8" >52.9%</td>
#     </tr>
#     <tr>
#       <th id="T_db0c7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_db0c7_row3_col0" class="data row3 col0" >black</td>
#       <td id="T_db0c7_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_db0c7_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_db0c7_row3_col3" class="data row3 col3" >0.0%</td>
#       <td id="T_db0c7_row3_col4" class="data row3 col4" >57</td>
#       <td id="T_db0c7_row3_col5" class="data row3 col5" >63</td>
#       <td id="T_db0c7_row3_col6" class="data row3 col6" >-2.75</td>
#       <td id="T_db0c7_row3_col7" class="data row3 col7" >37.5%</td>
#       <td id="T_db0c7_row3_col8" class="data row3 col8" >53.0%</td>
#     </tr>
#     <tr>
#       <th id="T_db0c7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_db0c7_row4_col0" class="data row4 col0" >gray</td>
#       <td id="T_db0c7_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_db0c7_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_db0c7_row4_col3" class="data row4 col3" >100.0%</td>
#       <td id="T_db0c7_row4_col4" class="data row4 col4" >63</td>
#       <td id="T_db0c7_row4_col5" class="data row4 col5" >58</td>
#       <td id="T_db0c7_row4_col6" class="data row4 col6" >2.50</td>
#       <td id="T_db0c7_row4_col7" class="data row4 col7" >45.5%</td>
#       <td id="T_db0c7_row4_col8" class="data row4 col8" >52.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 📊 Team report by jersey color
display(nice_team_table(team))
# Out:
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_8324/2085106526.py:69: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(margin_color, subset=["avg_margin"] if "avg_margin" in show.columns else [])
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_8324/2085106526.py:70: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(win_color, subset=["win%" if "win%" in show.columns else []])
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_8324/2085106526.py:71: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(efg_color, subset=["lmu_efg"] if "lmu_efg" in show.columns else [])
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_8324/2085106526.py:72: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(opp_efg_color, subset=["opp_efg"] if "opp_efg" in show.columns else [])
# <style type="text/css">
# #T_86ebf th {
#   font-size: 14px;
#   text-align: left;
# }
# #T_86ebf td {
#   text-align: left;
# }
# #T_86ebf_row0_col0, #T_86ebf_row0_col1, #T_86ebf_row0_col2, #T_86ebf_row0_col4, #T_86ebf_row0_col5, #T_86ebf_row1_col0, #T_86ebf_row1_col1, #T_86ebf_row1_col2, #T_86ebf_row1_col4, #T_86ebf_row1_col5, #T_86ebf_row2_col0, #T_86ebf_row2_col1, #T_86ebf_row2_col2, #T_86ebf_row2_col4, #T_86ebf_row2_col5, #T_86ebf_row3_col0, #T_86ebf_row3_col1, #T_86ebf_row3_col2, #T_86ebf_row3_col4, #T_86ebf_row3_col5, #T_86ebf_row4_col0, #T_86ebf_row4_col1, #T_86ebf_row4_col2, #T_86ebf_row4_col4, #T_86ebf_row4_col5 {
#   font-size: 14px;
# }
# #T_86ebf_row0_col3 {
#   background-color: rgba(0, 140, 255, 0.75);
#   font-size: 14px;
# }
# #T_86ebf_row0_col6 {
#   background-color: rgba(0, 200, 0, 0.25);
#   font-size: 14px;
# }
# #T_86ebf_row0_col7 {
#   background-color: rgba(255, 0, 0, 0.33);
#   font-size: 14px;
# }
# #T_86ebf_row0_col8 {
#   background-color: rgba(255, 0, 0, 0.14);
#   font-size: 14px;
# }
# #T_86ebf_row1_col3, #T_86ebf_row4_col3 {
#   background-color: rgba(0, 140, 255, 1.00);
#   font-size: 14px;
# }
# #T_86ebf_row1_col6 {
#   background-color: rgba(0, 200, 0, 0.23);
#   font-size: 14px;
# }
# #T_86ebf_row1_col7 {
#   background-color: rgba(255, 0, 0, 0.34);
#   font-size: 14px;
# }
# #T_86ebf_row1_col8 {
#   background-color: rgba(0, 200, 0, 0.65);
#   font-size: 14px;
# }
# #T_86ebf_row2_col3 {
#   background-color: rgba(0, 140, 255, 0.33);
#   font-size: 14px;
# }
# #T_86ebf_row2_col6 {
#   background-color: rgba(255, 0, 0, 0.01);
#   font-size: 14px;
# }
# #T_86ebf_row2_col7 {
#   background-color: rgba(255, 0, 0, 0.27);
#   font-size: 14px;
# }
# #T_86ebf_row2_col8 {
#   background-color: rgba(255, 0, 0, 0.29);
#   font-size: 14px;
# }
# #T_86ebf_row3_col3 {
#   background-color: rgba(0, 140, 255, 0.00);
#   font-size: 14px;
# }
# #T_86ebf_row3_col6 {
#   background-color: rgba(255, 0, 0, 0.18);
#   font-size: 14px;
# }
# #T_86ebf_row3_col7 {
#   background-color: rgba(255, 0, 0, 1.00);
#   font-size: 14px;
# }
# #T_86ebf_row3_col8 {
#   background-color: rgba(255, 0, 0, 0.30);
#   font-size: 14px;
# }
# #T_86ebf_row4_col6 {
#   background-color: rgba(0, 200, 0, 0.17);
#   font-size: 14px;
# }
# #T_86ebf_row4_col7 {
#   background-color: rgba(255, 0, 0, 0.45);
#   font-size: 14px;
# }
# #T_86ebf_row4_col8 {
#   background-color: rgba(255, 0, 0, 0.23);
#   font-size: 14px;
# }
# </style>
# <table id="T_86ebf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86ebf_level0_col0" class="col_heading level0 col0" >jerseycolor</th>
#       <th id="T_86ebf_level0_col1" class="col_heading level0 col1" >games</th>
#       <th id="T_86ebf_level0_col2" class="col_heading level0 col2" >wins</th>
#       <th id="T_86ebf_level0_col3" class="col_heading level0 col3" >win%</th>
#       <th id="T_86ebf_level0_col4" class="col_heading level0 col4" >pts_for</th>
#       <th id="T_86ebf_level0_col5" class="col_heading level0 col5" >pts_against</th>
#       <th id="T_86ebf_level0_col6" class="col_heading level0 col6" >avg_margin</th>
#       <th id="T_86ebf_level0_col7" class="col_heading level0 col7" >lmu_efg</th>
#       <th id="T_86ebf_level0_col8" class="col_heading level0 col8" >opp_efg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86ebf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86ebf_row0_col0" class="data row0 col0" >white</td>
#       <td id="T_86ebf_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_86ebf_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_86ebf_row0_col3" class="data row0 col3" >75.0%</td>
#       <td id="T_86ebf_row0_col4" class="data row0 col4" >74</td>
#       <td id="T_86ebf_row0_col5" class="data row0 col5" >67</td>
#       <td id="T_86ebf_row0_col6" class="data row0 col6" >3.75</td>
#       <td id="T_86ebf_row0_col7" class="data row0 col7" >46.7%</td>
#       <td id="T_86ebf_row0_col8" class="data row0 col8" >51.4%</td>
#     </tr>
#     <tr>
#       <th id="T_86ebf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_86ebf_row1_col0" class="data row1 col0" >blue</td>
#       <td id="T_86ebf_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_86ebf_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_86ebf_row1_col3" class="data row1 col3" >100.0%</td>
#       <td id="T_86ebf_row1_col4" class="data row1 col4" >64</td>
#       <td id="T_86ebf_row1_col5" class="data row1 col5" >57</td>
#       <td id="T_86ebf_row1_col6" class="data row1 col6" >3.50</td>
#       <td id="T_86ebf_row1_col7" class="data row1 col7" >46.6%</td>
#       <td id="T_86ebf_row1_col8" class="data row1 col8" >43.5%</td>
#     </tr>
#     <tr>
#       <th id="T_86ebf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_86ebf_row2_col0" class="data row2 col0" >red</td>
#       <td id="T_86ebf_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_86ebf_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_86ebf_row2_col3" class="data row2 col3" >33.3%</td>
#       <td id="T_86ebf_row2_col4" class="data row2 col4" >61</td>
#       <td id="T_86ebf_row2_col5" class="data row2 col5" >62</td>
#       <td id="T_86ebf_row2_col6" class="data row2 col6" >-0.17</td>
#       <td id="T_86ebf_row2_col7" class="data row2 col7" >47.3%</td>
#       <td id="T_86ebf_row2_col8" class="data row2 col8" >52.9%</td>
#     </tr>
#     <tr>
#       <th id="T_86ebf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_86ebf_row3_col0" class="data row3 col0" >black</td>
#       <td id="T_86ebf_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_86ebf_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_86ebf_row3_col3" class="data row3 col3" >0.0%</td>
#       <td id="T_86ebf_row3_col4" class="data row3 col4" >57</td>
#       <td id="T_86ebf_row3_col5" class="data row3 col5" >63</td>
#       <td id="T_86ebf_row3_col6" class="data row3 col6" >-2.75</td>
#       <td id="T_86ebf_row3_col7" class="data row3 col7" >37.5%</td>
#       <td id="T_86ebf_row3_col8" class="data row3 col8" >53.0%</td>
#     </tr>
#     <tr>
#       <th id="T_86ebf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_86ebf_row4_col0" class="data row4 col0" >gray</td>
#       <td id="T_86ebf_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_86ebf_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_86ebf_row4_col3" class="data row4 col3" >100.0%</td>
#       <td id="T_86ebf_row4_col4" class="data row4 col4" >63</td>
#       <td id="T_86ebf_row4_col5" class="data row4 col5" >58</td>
#       <td id="T_86ebf_row4_col6" class="data row4 col6" >2.50</td>
#       <td id="T_86ebf_row4_col7" class="data row4 col7" >45.5%</td>
#       <td id="T_86ebf_row4_col8" class="data row4 col8" >52.3%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Player breakdown (filter + sort)

# %%
import ipywidgets as widgets

options = ["(all)"] + [c for c in team["jerseycolor"].dropna().astype(str).unique().tolist()]
dropdown = widgets.Dropdown(options=options, value="(all)", description="Jersey:", layout=widgets.Layout(width="250px"))
sort_dropdown = widgets.Dropdown(
    options=["eFG%","pts_mean","ast_mean","reb_mean","gp"],
    value="eFG%",
    description="Sort:",
    layout=widgets.Layout(width="250px")
)
ascending_toggle = widgets.Checkbox(value=False, description="Ascending", indent=False)

display(widgets.HBox([dropdown, sort_dropdown, ascending_toggle]))

def show_filtered(jersey, sort_by, ascending):
    if jersey == "(all)":
        dfp = players.copy()
    else:
        dfp = players[players["jerseycolor"].astype(str) == jersey].copy()
    if sort_by in dfp.columns:
        dfp = dfp.sort_values(sort_by, ascending=ascending)
    display(nice_player_table(dfp.reset_index(drop=True)))

out = widgets.interactive_output(show_filtered, {
    "jersey": dropdown,
    "sort_by": sort_dropdown,
    "ascending": ascending_toggle
})
display(out)
# Out:
# HBox(children=(Dropdown(description='Jersey:', layout=Layout(width='250px'), options=('(all)', 'white', 'blue'…
# Output()
